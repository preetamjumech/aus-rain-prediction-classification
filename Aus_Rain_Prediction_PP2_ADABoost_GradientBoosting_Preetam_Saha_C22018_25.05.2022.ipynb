# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
import warnings

warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("weatherAUS_Rain_Tomorrow.csv")

# %%
df1.head()
# Out:
#          Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0   5/18/2009        Hobart      5.1     14.3       0.0          1.8
# 1  07-03-2009    Launceston      1.1     14.5       0.4          NaN
# 2   2/18/2010   Williamtown     19.7     26.2       0.0          7.2
# 3  03-04-2010  PerthAirport     16.6     28.0       0.0          9.0
# 4  09-09-2010     GoldCoast     14.6     25.3       0.0          NaN
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0       8.9          NW           30.0        WSW  ...        65.0
# 1       NaN         SSW           50.0          E  ...        99.0
# 2       7.2         SSE           41.0        SSE  ...        48.0
# 3      11.3          SW           54.0        SSE  ...        50.0
# 4       NaN         NNW           43.0        WNW  ...        64.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0         47.0       1023.1       1022.2       1.0       1.0      9.1
# 1         46.0       1001.5       1002.4       NaN       NaN      1.3
# 2         50.0       1020.9       1021.9       6.0       4.0     22.7
# 3         41.0       1018.3       1014.9       6.0       1.0     20.0
# 4         67.0       1020.3       1015.0       NaN       NaN     22.2
#
#    Temp3pm  RainToday  RainTomorrow
# 0     13.3         No            No
# 1     13.7         No            No
# 2     24.4         No            No
# 3     26.1         No            No
# 4     22.6         No            No
#
# [5 rows x 23 columns]

# %%
df1.shape
# Out:
# (36881, 23)

# %%
df1.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            338
# MaxTemp            242
# Rainfall           626
# Evaporation      12846
# Sunshine         13564
# WindGustDir       3368
# WindGustSpeed     3361
# WindDir9am        2809
# WindDir3pm         962
# WindSpeed9am       662
# WindSpeed3pm       646
# Humidity9am        570
# Humidity3pm        511
# Pressure9am       3572
# Pressure3pm       3552
# Cloud9am         12500
# Cloud3pm         12982
# Temp9am            487
# Temp3pm            444
# RainToday          626
# RainTomorrow       620
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36881 entries, 0 to 36880
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           36881 non-null  object
#  1   Location       36881 non-null  object
#  2   MinTemp        36543 non-null  float64
#  3   MaxTemp        36639 non-null  float64
#  4   Rainfall       36255 non-null  float64
#  5   Evaporation    24035 non-null  float64
#  6   Sunshine       23317 non-null  float64
#  7   WindGustDir    33513 non-null  object
#  8   WindGustSpeed  33520 non-null  float64
#  9   WindDir9am     34072 non-null  object
#  10  WindDir3pm     35919 non-null  object
#  11  WindSpeed9am   36219 non-null  float64
#  12  WindSpeed3pm   36235 non-null  float64
#  13  Humidity9am    36311 non-null  float64
#  14  Humidity3pm    36370 non-null  float64
#  15  Pressure9am    33309 non-null  float64
#  16  Pressure3pm    33329 non-null  float64
#  17  Cloud9am       24381 non-null  float64
#  18  Cloud3pm       23899 non-null  float64
#  19  Temp9am        36394 non-null  float64
#  20  Temp3pm        36437 non-null  float64
#  21  RainToday      36255 non-null  object
#  22  RainTomorrow   36261 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 6.5+ MB

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RainTomorrow]
# Index: []
#
# [0 rows x 23 columns]

# %%
import missingno as msno
msno.matrix(df1,labels=True, sort="descending")
# Out:
# <AxesSubplot:>

# %%
df=df1[~df1["RainTomorrow"].isnull()==True]
df
# Out:
#              Date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       5/18/2009        Hobart      5.1     14.3       0.0          1.8
# 1      07-03-2009    Launceston      1.1     14.5       0.4          NaN
# 2       2/18/2010   Williamtown     19.7     26.2       0.0          7.2
# 3      03-04-2010  PerthAirport     16.6     28.0       0.0          9.0
# 4      09-09-2010     GoldCoast     14.6     25.3       0.0          NaN
# ...           ...           ...      ...      ...       ...          ...
# 36876   6/14/2011         Perth     10.1     14.2       7.4          3.4
# 36877   9/24/2010  PerthAirport      6.3     26.0       0.0          5.0
# 36878  05-06-2011        Darwin     20.5     31.7       0.0          7.0
# 36879  10-12-2010         Perth      6.3     23.3       0.0          5.2
# 36880  12/22/2010     Nuriootpa      9.4     26.3       0.0          4.8
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0           8.9          NW           30.0        WSW  ...        65.0
# 1           NaN         SSW           50.0          E  ...        99.0
# 2           7.2         SSE           41.0        SSE  ...        48.0
# 3          11.3          SW           54.0        SSE  ...        50.0
# 4           NaN         NNW           43.0        WNW  ...        64.0
# ...         ...         ...            ...        ...  ...         ...
# 36876       0.0         NNE           46.0        NNE  ...        84.0
# 36877      10.6           W           37.0          N  ...        38.0
# 36878      11.1           E           37.0          E  ...        54.0
# 36879      11.6         SSW           39.0          E  ...        50.0
# 36880      12.2          SE           35.0        ENE  ...        50.0
#
#        Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0             47.0       1023.1       1022.2       1.0       1.0      9.1
# 1             46.0       1001.5       1002.4       NaN       NaN      1.3
# 2             50.0       1020.9       1021.9       6.0       4.0     22.7
# 3             41.0       1018.3       1014.9       6.0       1.0     20.0
# 4             67.0       1020.3       1015.0       NaN       NaN     22.2
# ...            ...          ...          ...       ...       ...      ...
# 36876         81.0       1016.2       1014.5       7.0       8.0     10.4
# 36877         45.0       1024.2       1021.5       1.0       1.0     18.4
# 36878         39.0       1012.6       1009.0       2.0       5.0     25.7
# 36879         41.0       1023.9       1019.9       0.0       1.0     16.4
# 36880         28.0       1017.5       1014.7       4.0       4.0     16.7
#
#        Temp3pm  RainToday  RainTomorrow
# 0         13.3         No            No
# 1         13.7         No            No
# 2         24.4         No            No
# 3         26.1         No            No
# 4         22.6         No            No
# ...        ...        ...           ...
# 36876     13.9        Yes           Yes
# 36877     23.5         No            No
# 36878     30.5         No            No
# 36879     20.9         No            No
# 36880     25.3         No            No
#
# [36261 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            205
# MaxTemp             85
# Rainfall           349
# Evaporation      12392
# Sunshine         13155
# WindGustDir       3022
# WindGustSpeed     3015
# WindDir9am        2614
# WindDir3pm         801
# WindSpeed9am       506
# WindSpeed3pm       490
# Humidity9am        416
# Humidity3pm        358
# Pressure9am       3354
# Pressure3pm       3328
# Cloud9am         12038
# Cloud3pm         12517
# Temp9am            335
# Temp3pm            293
# RainToday          349
# RainTomorrow         0
# dtype: int64

# %%
# For each numerical feature compute number of unique entries
unique_values = df.select_dtypes(include="number").nunique().sort_values()

# Plot information with y-axis in log-scale
unique_values.plot.bar( figsize=(15, 4), title="Unique values per feature")
# Out:
# <AxesSubplot:title={'center':'Unique values per feature'}>

# %%
df.select_dtypes(include="number").shape[1]
# Out:
# 16

# %%
# Display non-numerical features
df.select_dtypes(exclude="number").head()
# Out:
#          Date      Location WindGustDir WindDir9am WindDir3pm RainToday  \
# 0   5/18/2009        Hobart          NW        WSW        SSE        No
# 1  07-03-2009    Launceston         SSW          E         SW        No
# 2   2/18/2010   Williamtown         SSE        SSE        SSE        No
# 3  03-04-2010  PerthAirport          SW        SSE         SW        No
# 4  09-09-2010     GoldCoast         NNW        WNW          N        No
#
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %%
df.describe(exclude="number")
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count        36261     36261       33239      33647      35460     35912
# unique        1473        46          16         16         16         2
# top     03-03-2009  Canberra          SE          N         SE        No
# freq            41      1077        2389       2820       2921     27505
#
#        RainTomorrow
# count         36261
# unique            2
# top              No
# freq          27732

# %%
categorical=[]
for col in df.columns:
    if df[col].dtype == "O":
        categorical.append(col)
print(f"There are {len(categorical)} categorical variables, --> {categorical}")
# Out:
# There are 7 categorical variables, --> ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
df[categorical].isnull().sum()
# Out:
# Date               0
# Location           0
# WindGustDir     3022
# WindDir9am      2614
# WindDir3pm       801
# RainToday        349
# RainTomorrow       0
# dtype: int64

# %%
for cat in categorical:
    print(cat, ' contains ', df[cat].nunique(), ' labels')
# Out:
# Date  contains  1473  labels
# Location  contains  46  labels
# WindGustDir  contains  16  labels
# WindDir9am  contains  16  labels
# WindDir3pm  contains  16  labels
# RainToday  contains  2  labels
# RainTomorrow  contains  2  labels

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # Date

# %%
df["Date"].dtype
# Out:
# dtype('O')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year

df['Year'].head()
# Out:
# 0    2009
# 1    2009
# 2    2010
# 3    2010
# 4    2010
# Name: Year, dtype: int64

# %%
df['Month'] = df['Date'].dt.month

df['Month'].head()
# Out:
# 0    5
# 1    7
# 2    2
# 3    3
# 4    9
# Name: Month, dtype: int64

# %%
df['Day'] = df['Date'].dt.day

df['Day'].head()
# Out:
# 0    18
# 1     3
# 2    18
# 3     4
# 4     9
# Name: Day, dtype: int64

# %%
df.drop('Date', axis=1, inplace = True)

# %%
df.head(15)
# Out:
#             Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0             Hobart      5.1     14.3       0.0          1.8       8.9
# 1         Launceston      1.1     14.5       0.4          NaN       NaN
# 2        Williamtown     19.7     26.2       0.0          7.2       7.2
# 3       PerthAirport     16.6     28.0       0.0          9.0      11.3
# 4          GoldCoast     14.6     25.3       0.0          NaN       NaN
# 5            Mildura     15.7     27.3       0.0         11.2       5.6
# 6          Nuriootpa      9.8     23.9       0.0          4.4      10.5
# 7          NorahHead     18.7     27.6       3.0          NaN       NaN
# 8         Townsville     23.6     30.1       0.0         11.4      10.8
# 9       MountGambier      8.5     22.9       1.4          4.2      12.5
# 10  MelbourneAirport      8.7     20.9       0.0          2.8       9.5
# 11         Nuriootpa     16.4     28.0       1.0          5.0       1.7
# 12        Launceston     12.9     21.7       1.4         18.0       NaN
# 13     SydneyAirport     12.1     20.9       0.0          4.4       6.9
# 14  MelbourneAirport     13.2     19.8       0.0          4.6      11.3
#
#    WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 0           NW           30.0        WSW        SSE  ...       1022.2
# 1          SSW           50.0          E         SW  ...       1002.4
# 2          SSE           41.0        SSE        SSE  ...       1021.9
# 3           SW           54.0        SSE         SW  ...       1014.9
# 4          NNW           43.0        WNW          N  ...       1015.0
# 5            N           65.0        ENE         SW  ...        995.5
# 6           SE           35.0        ENE        NNE  ...       1013.9
# 7          SSE           41.0        WNW          S  ...       1011.0
# 8            E           57.0        ESE          E  ...       1018.0
# 9          SSW           41.0        SSE        SSE  ...       1022.1
# 10           S           19.0        WNW        SSE  ...       1020.8
# 11         WSW           65.0        WNW          W  ...       1008.5
# 12           S           24.0        SSE        NNE  ...       1024.2
# 13           E           37.0         NW          E  ...       1006.4
# 14           S           37.0        SSE         SE  ...       1021.9
#
#     Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 0        1.0       1.0      9.1     13.3         No            No  2009
# 1        NaN       NaN      1.3     13.7         No            No  2009
# 2        6.0       4.0     22.7     24.4         No            No  2010
# 3        6.0       1.0     20.0     26.1         No            No  2010
# 4        NaN       NaN     22.2     22.6         No            No  2010
# 5        8.0       7.0     18.1     18.5         No           Yes  2011
# 6        3.0       4.0     15.5     23.0         No            No  2011
# 7        NaN       NaN     22.4     24.0        Yes            No  2010
# 8        4.0       2.0     27.4     27.9         No            No  2009
# 9        1.0       2.0     16.4     22.1        Yes            No  2010
# 10       5.0       2.0     11.5     20.0         No            No  2009
# 11       8.0       8.0     26.1     16.4         No           Yes  2009
# 12       NaN       NaN     15.2     19.8        Yes            No  2009
# 13       5.0       6.0     15.5     18.3         No            No  2011
# 14       6.0       2.0     14.9     18.9         No            No  2009
#
#     Month  Day
# 0       5   18
# 1       7    3
# 2       2   18
# 3       3    4
# 4       9    9
# 5       9   28
# 6      10   13
# 7       4    8
# 8      10   19
# 9       2   23
# 10      4   20
# 11      3    3
# 12      2   16
# 13     10   10
# 14     12   14
#
# [15 rows x 25 columns]

# %% [markdown]
# # Location

# %%
print('Location contains', len(df.Location.unique()), 'labels')
# Out:
# Location contains 46 labels

# %%
df.Location.unique()
# Out:
# array(['Hobart', 'Launceston', 'Williamtown', 'PerthAirport', 'GoldCoast',
#        'Mildura', 'Nuriootpa', 'NorahHead', 'Townsville', 'MountGambier',
#        'MelbourneAirport', 'SydneyAirport', 'Darwin', 'Newcastle',
#        'Watsonia', 'CoffsHarbour', 'MountGinini', 'Sale', 'PearceRAAF',
#        'Adelaide', 'Albury', 'Richmond', 'Walpole', 'Cairns',
#        'BadgerysCreek', 'AliceSprings', 'Bendigo', 'SalmonGums',
#        'Canberra', 'Ballarat', 'Woomera', 'Penrith', 'WaggaWagga',
#        'Dartmoor', 'Perth', 'Cobar', 'Sydney', 'Melbourne',
#        'NorfolkIsland', 'Tuggeranong', 'Albany', 'Moree', 'Wollongong',
#        'Portland', 'Brisbane', 'Witchcliffe'], dtype=object)

# %%
plt.figure(figsize =(13, 4))
df["Location"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # WindGustDir

# %%
print('WindGustDir', len(df.WindGustDir.unique()), 'labels')
# Out:
# WindGustDir 17 labels

# %%
df['WindGustDir'].unique()
# Out:
# array(['NW', 'SSW', 'SSE', 'SW', 'NNW', 'N', 'SE', 'E', 'S', 'WSW', 'W',
#        nan, 'NE', 'NNE', 'WNW', 'ESE', 'ENE'], dtype=object)

# %%
plt.figure(figsize =(13, 4))
df["WindGustDir"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # WindDir9am

# %%
print('WindDir9am contains', len(df['WindDir9am'].unique()), 'labels')
# Out:
# WindDir9am contains 17 labels

# %%
df['WindDir9am'].unique()
# Out:
# array(['WSW', 'E', 'SSE', 'WNW', 'ENE', 'ESE', 'NW', nan, 'NE', 'SE',
#        'NNW', 'N', 'W', 'NNE', 'S', 'SW', 'SSW'], dtype=object)

# %%
plt.figure(figsize =(13, 4))
df["WindGustDir"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # RainToday

# %%
print('RainToday contains', len(df['RainToday'].unique()), 'labels')
# Out:
# RainToday contains 3 labels

# %%
df['RainToday'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df.RainToday.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Numerical Variables

# %%
numerical=[]
for num in df.columns:
    if df[num].dtype != "O":
        numerical.append(num)
print(f"There are {len(numerical)} numerical variables, --> {numerical}")
# Out:
# There are 19 numerical variables, --> ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'Year', 'Month', 'Day']

# %%
plt.figure(figsize=(12,6))
df[numerical].isnull().sum().sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df[numerical].describe().T
# Out:
#                  count         mean        std     min     25%     50%  \
# MinTemp        36056.0    12.252549   6.387194    -8.5     7.6    12.1
# MaxTemp        36176.0    22.968045   6.978047    -3.1    17.8    22.4
# Rainfall       35912.0     2.548953   9.075119     0.0     0.0     0.0
# Evaporation    23869.0     5.192928   3.771129     0.0     2.6     4.6
# Sunshine       23106.0     7.545516   3.832795     0.0     4.7     8.4
# WindGustSpeed  33246.0    40.382572  13.537023     7.0    31.0    39.0
# WindSpeed9am   35755.0    14.213453   8.986999     0.0     7.0    13.0
# WindSpeed3pm   35771.0    18.881077   8.795042     0.0    13.0    19.0
# Humidity9am    35845.0    69.109137  18.306222     2.0    57.0    70.0
# Humidity3pm    35903.0    52.255466  20.323059     1.0    38.0    53.0
# Pressure9am    32907.0  1017.278254   7.178602   982.9  1012.5  1017.3
# Pressure3pm    32933.0  1014.960534   7.077853   980.2  1010.1  1015.0
# Cloud9am       24223.0     4.326756   2.848301     0.0     1.0     5.0
# Cloud3pm       23744.0     4.460580   2.663079     0.0     2.0     5.0
# Temp9am        35926.0    16.927841   6.423823    -5.9    12.3    16.6
# Temp3pm        35968.0    21.512503   6.814023    -5.1    16.5    20.9
# Year           36261.0  2009.934668   0.947640  2007.0  2009.0  2010.0
# Month          36261.0     6.568214   3.561409     1.0     3.0     7.0
# Day            36261.0    15.720471   8.804399     1.0     8.0    16.0
#
#                     75%     max
# MinTemp          17.000    30.5
# MaxTemp          27.925    48.1
# Rainfall          0.800   371.0
# Evaporation       7.000    81.2
# Sunshine         10.600    14.3
# WindGustSpeed    48.000   135.0
# WindSpeed9am     20.000    87.0
# WindSpeed3pm     24.000    87.0
# Humidity9am      83.000   100.0
# Humidity3pm      66.000   100.0
# Pressure9am    1022.200  1041.0
# Pressure3pm    1019.800  1039.6
# Cloud9am          7.000     9.0
# Cloud3pm          7.000     8.0
# Temp9am          21.500    37.7
# Temp3pm          26.200    46.1
# Year           2011.000  2012.0
# Month            10.000    12.0
# Day              23.000    31.0

# %%
cor=df[numerical].corr()

# %%
plt.figure(figsize=(14,6))
sns.heatmap(cor,annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
# draw boxplots to visualize outliers

plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
fig = df.boxplot(column='Rainfall')
fig.set_title('')
fig.set_ylabel('Rainfall')

plt.subplot(2, 2, 2)
fig = df.boxplot(column='Evaporation')
fig.set_title('')
fig.set_ylabel('Evaporation')

plt.subplot(2, 2, 3)
fig = df.boxplot(column='WindSpeed9am')
fig.set_title('')
fig.set_ylabel('WindSpeed9am')

plt.subplot(2, 2, 4)
fig = df.boxplot(column='WindSpeed3pm')
fig.set_title('')
fig.set_ylabel('WindSpeed3pm')
# Out:
# Text(0, 0.5, 'WindSpeed3pm')

# %%
plt.figure(figsize=(15,10))

plt.subplot(2, 2, 1)
fig = df.Rainfall.hist(bins=15)
fig.set_xlabel('Rainfall')

plt.subplot(2, 2, 2)
fig = df.Evaporation.hist(bins=15)
fig.set_xlabel('Evaporation')

plt.subplot(2, 2, 3)
fig = df.WindSpeed9am.hist(bins=15)
fig.set_xlabel('WindSpeed9am')

plt.subplot(2, 2, 4)
fig = df.WindSpeed3pm.hist(bins=15)
fig.set_xlabel('WindSpeed3pm')
# Out:
# Text(0.5, 0, 'WindSpeed3pm')

# %%
IQR = df.Rainfall.quantile(0.75) - df.Rainfall.quantile(0.25)
Lower_fence = df.Rainfall.quantile(0.25) - (IQR * 3)
Upper_fence = df.Rainfall.quantile(0.75) + (IQR * 3)
print(f'Rainfall outliers are values < {Lower_fence} or > {Upper_fence}.')
# Out:
# Rainfall outliers are values < -2.4000000000000004 or > 3.2.

# %%
df[df["Rainfall"] < -2.4]
# Out:
# Empty DataFrame
# Columns: [Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RainTomorrow, Year, Month, Day]
# Index: []
#
# [0 rows x 25 columns]

# %%
df[df["Rainfall"] >3.2]
# Out:
#           Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 15      Launceston     10.7     18.0       6.0          NaN       NaN
# 21       NorahHead     13.8     19.2      18.6          NaN       NaN
# 23      Launceston     14.4     21.1       4.4          NaN       NaN
# 33        Adelaide     12.5     20.0       4.2          NaN       9.9
# 34          Albury      6.9     13.7       4.4          NaN       NaN
# ...            ...      ...      ...       ...          ...       ...
# 36867       Sydney     19.2     27.4      17.0          8.4       6.6
# 36868       Albany     18.2     19.5      12.6          5.4       0.0
# 36869  Witchcliffe      7.8     19.4       7.8          NaN       NaN
# 36872     Watsonia      9.3     18.2      14.2          4.0      10.2
# 36876        Perth     10.1     14.2       7.4          3.4       0.0
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 15              W           33.0        SSE         NW  ...       1000.1
# 21            SSE           61.0         SE          S  ...       1021.4
# 23              N           57.0        ENE          N  ...       1005.8
# 33             SW           33.0          S        WSW  ...       1022.3
# 34             SE           46.0        ESE        ESE  ...       1008.1
# ...           ...            ...        ...        ...  ...          ...
# 36867         NaN            NaN        WNW          E  ...       1007.8
# 36868         NaN            NaN          S        SSE  ...       1013.8
# 36869         WSW           28.0        NNW         SW  ...       1006.8
# 36872         WSW           24.0        NaN         SE  ...       1018.9
# 36876         NNE           46.0        NNE          N  ...       1014.5
#
#        Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 15          NaN       NaN     14.7     15.9        Yes           Yes  2009
# 21          NaN       NaN     15.9     15.6        Yes           Yes  2010
# 23          NaN       NaN     21.0     17.4        Yes           Yes  2010
# 33          NaN       NaN     16.2     19.7        Yes            No  2010
# 34          7.0       NaN      8.4     13.0        Yes            No  2009
# ...         ...       ...      ...      ...        ...           ...   ...
# 36867       2.0       3.0     21.7     25.0        Yes            No  2009
# 36868       8.0       7.0     18.8     19.0        Yes            No  2010
# 36869       NaN       NaN     13.0     17.7        Yes           Yes  2009
# 36872       4.0       0.0     12.4     17.5        Yes            No  2009
# 36876       7.0       8.0     10.4     13.9        Yes           Yes  2011
#
#        Month  Day
# 15        11   22
# 21        11    5
# 23        10   31
# 33         4   25
# 34         6   26
# ...      ...  ...
# 36867      3   15
# 36868      1   25
# 36869      6   25
# 36872      9   18
# 36876      6   14
#
# [5558 rows x 25 columns]

# %%
IQR = df.Evaporation.quantile(0.75) - df.Evaporation.quantile(0.25)
Lower_fence = df.Evaporation.quantile(0.25) - (IQR * 3)
Upper_fence = df.Evaporation.quantile(0.75) + (IQR * 3)
print(f'Evaporation outliers are values < {Lower_fence} or > {Upper_fence}.')
# Out:
# Evaporation outliers are values < -10.600000000000001 or > 20.200000000000003.

# %%
df[df["Evaporation"] < -10.6]
# Out:
# Empty DataFrame
# Columns: [Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RainTomorrow, Year, Month, Day]
# Index: []
#
# [0 rows x 25 columns]

# %%
df[df["Evaporation"] > 20.2]
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 62          Woomera     24.4     43.6       0.0         32.2       NaN
# 438           Moree     14.4     30.0       0.0         20.4      11.8
# 1817          Cobar      7.7     24.5       0.0         24.6       NaN
# 2078   AliceSprings     30.3     40.5       0.0         20.8       7.0
# 2334       Richmond     15.4     28.2       0.0         21.0       NaN
# ...             ...      ...      ...       ...          ...       ...
# 34905     Nuriootpa     19.1     36.7       0.0         25.8       6.1
# 34940       Mildura     16.4     29.7       0.0         21.0      11.8
# 35046      Adelaide     18.2     26.1       0.0         22.6       9.8
# 36422      Richmond      9.2     21.5       0.0         30.2       NaN
# 36708      Adelaide     14.5     35.2       0.0         22.6      12.4
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 62            SSW           52.0        NNE        WSW  ...       1005.8
# 438             E           37.0          E          E  ...       1017.2
# 1817            E           48.0          E        ENE  ...       1015.9
# 2078          WSW           61.0        WNW        SSW  ...       1003.6
# 2334          ESE           37.0        SSE        ENE  ...       1011.6
# ...           ...            ...        ...        ...  ...          ...
# 34905         WNW           69.0          N         NW  ...       1010.6
# 34940           S           52.0          S        SSW  ...       1015.8
# 35046         SSE           39.0          S          S  ...       1015.4
# 36422           W           44.0          W          W  ...       1006.0
# 36708           N           28.0         SW         SW  ...       1013.2
#
#        Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 62          0.0       NaN     33.8     41.0         No            No  2011
# 438         1.0       3.0     20.9     28.7         No            No  2011
# 1817        6.0       1.0     15.8     23.3         No            No  2011
# 2078        3.0       5.0     35.9     39.0         No            No  2009
# 2334        NaN       NaN     21.3     27.4         No            No  2010
# ...         ...       ...      ...      ...        ...           ...   ...
# 34905       6.0       7.0     29.4     36.0         No            No  2009
# 34940       4.0       4.0     18.4     25.9         No            No  2009
# 35046       NaN       NaN     20.3     24.9         No            No  2010
# 36422       NaN       NaN     16.1     20.9         No            No  2009
# 36708       NaN       NaN     21.2     33.1         No            No  2009
#
#        Month  Day
# 62        12   24
# 438        3    7
# 1817       9   26
# 2078      11   18
# 2334      12   13
# ...      ...  ...
# 34905     11    2
# 34940      1   15
# 35046      2   15
# 36422      9   28
# 36708      1   12
#
# [107 rows x 25 columns]

# %%
IQR = df.WindSpeed9am.quantile(0.75) - df.WindSpeed9am.quantile(0.25)
Lower_fence = df.WindSpeed9am.quantile(0.25) - (IQR * 3)
Upper_fence = df.WindSpeed9am.quantile(0.75) + (IQR * 3)
print(f'WindSpeed9am outliers are values < {Lower_fence} or > {Upper_fence}.')
# Out:
# WindSpeed9am outliers are values < -32.0 or > 59.0.

# %%
df[df["WindSpeed9am"] < -10.6]
# Out:
# Empty DataFrame
# Columns: [Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RainTomorrow, Year, Month, Day]
# Index: []
#
# [0 rows x 25 columns]

# %%
df[df["WindSpeed9am"] > 20.2]
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 3      PerthAirport     16.6     28.0       0.0          9.0      11.3
# 8        Townsville     23.6     30.1       0.0         11.4      10.8
# 21        NorahHead     13.8     19.2      18.6          NaN       NaN
# 22           Darwin     24.9     33.2       0.0          7.2       8.0
# 24     CoffsHarbour     20.3     30.0       0.0          7.0       NaN
# ...             ...      ...      ...       ...          ...       ...
# 36859    SalmonGums     14.2     29.0       0.0          NaN       NaN
# 36861    WaggaWagga     17.8     23.4       0.0          4.6       7.1
# 36863    Wollongong     12.8     15.9       1.0          NaN       NaN
# 36868        Albany     18.2     19.5      12.6          5.4       0.0
# 36871    SalmonGums      8.3     19.6       0.0          NaN       NaN
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 3              SW           54.0        SSE         SW  ...       1014.9
# 8               E           57.0        ESE          E  ...       1018.0
# 21            SSE           61.0         SE          S  ...       1021.4
# 22              E           48.0        ESE          E  ...       1008.6
# 24            NNE           57.0        NNW         NE  ...       1008.4
# ...           ...            ...        ...        ...  ...          ...
# 36859         WSW           52.0        NNW        WSW  ...          NaN
# 36861         WSW           46.0        WSW         SW  ...       1009.5
# 36863          SE           43.0          S        ESE  ...       1036.4
# 36868         NaN            NaN          S        SSE  ...       1013.8
# 36871         NNE           54.0          N        NNE  ...          NaN
#
#        Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 3           6.0       1.0     20.0     26.1         No            No  2010
# 8           4.0       2.0     27.4     27.9         No            No  2009
# 21          NaN       NaN     15.9     15.6        Yes           Yes  2010
# 22          4.0       7.0     27.9     32.2         No            No  2010
# 24          6.0       3.0     25.6     27.1         No            No  2011
# ...         ...       ...      ...      ...        ...           ...   ...
# 36859       NaN       NaN     27.5     21.0         No            No  2009
# 36861       7.0       5.0     19.5     22.1         No            No  2011
# 36863       8.0       8.0     14.1     14.1         No           Yes  2010
# 36868       8.0       7.0     18.8     19.0        Yes            No  2010
# 36871       NaN       NaN     14.9     17.7         No           Yes  2010
#
#        Month  Day
# 3          3    4
# 8         10   19
# 21        11    5
# 22         5    3
# 24        11   22
# ...      ...  ...
# 36859     10   10
# 36861      3    1
# 36863      6   22
# 36868      1   25
# 36871      8   12
#
# [7030 rows x 25 columns]

# %%
IQR = df.WindSpeed3pm.quantile(0.75) - df.WindSpeed3pm.quantile(0.25)
Lower_fence = df.WindSpeed3pm.quantile(0.25) - (IQR * 3)
Upper_fence = df.WindSpeed3pm.quantile(0.75) + (IQR * 3)
print(f'WindSpeed3pm outliers are values < {Lower_fence} or > {Upper_fence}.')
# Out:
# WindSpeed3pm outliers are values < -20.0 or > 57.0.

# %%
df[df["WindSpeed9am"] < -20.0]
# Out:
# Empty DataFrame
# Columns: [Location, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RainTomorrow, Year, Month, Day]
# Index: []
#
# [0 rows x 25 columns]

# %%
df[df["WindSpeed9am"] >57.0]
# Out:
#                Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 1412          Newcastle     16.4     19.5       0.0          NaN       NaN
# 2887   MelbourneAirport      8.8     17.5       0.0          4.0       6.5
# 5911      SydneyAirport     11.7     16.4       1.8          3.4       9.3
# 9522          Newcastle     16.0     21.8       1.2          NaN       NaN
# 10732  MelbourneAirport     14.0     26.6       0.0          8.8       6.2
# 15775              Sale      6.6     16.9       0.0          4.4       7.2
# 17236         Newcastle      9.2     19.4       0.0          NaN       NaN
# 19775        Wollongong     16.3     21.3       3.6          NaN       NaN
# 19998         Melbourne     10.5     19.3       0.0          4.0       6.5
# 21091        Townsville     23.3     28.6       NaN          NaN       1.2
# 25295         NorahHead      9.2     17.6      44.0          NaN       NaN
# 27754         Melbourne     14.0     24.5       0.0         11.4       6.9
# 30837     SydneyAirport     16.9     22.1       1.0          5.6      11.3
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 1412          NaN            NaN         NW         NW  ...          NaN
# 2887            N           89.0          N          N  ...       1009.2
# 5911            W           93.0        WNW        WSW  ...       1004.0
# 9522          NaN            NaN         NW         NW  ...          NaN
# 10732           N           80.0          N          N  ...       1006.4
# 15775           W          104.0        WSW        WSW  ...       1008.5
# 17236         NaN            NaN         NW         NW  ...          NaN
# 19775         WNW          126.0        WNW        WSW  ...       1009.9
# 19998           N           89.0          N          N  ...       1010.3
# 21091           E          135.0        ENE        ENE  ...       1006.0
# 25295           S          111.0          S        SSW  ...       1011.6
# 27754           N           91.0          N          N  ...       1000.6
# 30837          NW           91.0         NW        WNW  ...       1009.9
#
#        Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 1412        0.0       2.0     16.6     19.0         No            No  2009
# 2887        7.0       1.0     10.4     16.9         No            No  2009
# 5911        3.0       3.0     12.4     15.7        Yes            No  2010
# 9522        1.0       4.0     18.2     21.2        Yes            No  2010
# 10732       7.0       8.0     18.6     24.6         No           Yes  2011
# 15775       6.0       6.0     14.4     13.7         No            No  2009
# 17236       2.0       1.0     14.5     18.5         No            No  2009
# 19775       NaN       NaN     17.4     20.0        Yes            No  2010
# 19998       5.0       2.0     12.7     18.2         No            No  2009
# 21091       8.0       8.0     27.2     26.7        NaN           Yes  2011
# 25295       NaN       NaN     15.2     15.5        Yes           Yes  2011
# 27754       6.0       3.0     17.4     23.1         No            No  2008
# 30837       1.0       1.0     18.8     21.0         No            No  2010
#
#        Month  Day
# 1412       9   23
# 2887       8   15
# 5911      10   16
# 9522       9    5
# 10732     10   28
# 15775      4   15
# 17236      9   27
# 19775      9    5
# 19998      8   15
# 21091      2    3
# 25295      7   20
# 27754      9   12
# 30837      9    5
#
# [13 rows x 25 columns]

# %% [markdown]
# # Imputation of Missing values

# %%
for col in numerical:
    col_median=df[col].median()
    df[col].fillna(col_median, inplace=True)

# %%
df[numerical].isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# Year             0
# Month            0
# Day              0
# dtype: int64

# %%
categorical1=["Location","WindGustDir","WindDir9am","WindDir3pm","RainToday"]

# %%
for col in categorical1:
    col_mode=df[col].mode()[0]
    df[col].fillna(col_mode, inplace=True)

# %%
df[categorical1].isnull().sum()
# Out:
# Location       0
# WindGustDir    0
# WindDir9am     0
# WindDir3pm     0
# RainToday      0
# dtype: int64

# %%
def outliers_remove(col,top):
    return np.where(df[col]>top,top,df[col])

# %%
df["Rainfall"]=outliers_remove("Rainfall",3.2)

# %%
df.hist("Rainfall")
# Out:
# array([[<AxesSubplot:title={'center':'Rainfall'}>]], dtype=object)

# %%
df["Rainfall"]
# Out:
# 0        0.0
# 1        0.4
# 2        0.0
# 3        0.0
# 4        0.0
#         ...
# 36876    3.2
# 36877    0.0
# 36878    0.0
# 36879    0.0
# 36880    0.0
# Name: Rainfall, Length: 36261, dtype: float64

# %%
df["Rainfall"].describe()
# Out:
# count    36261.000000
# mean         0.709512
# std          1.207785
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.800000
# max          3.200000
# Name: Rainfall, dtype: float64

# %%
df["Evaporation"]=outliers_remove("Evaporation",20.2)

# %%
df["Evaporation"].describe()
# Out:
# count    36261.000000
# mean         4.965806
# std          2.841683
# min          0.000000
# 25%          3.600000
# 50%          4.600000
# 75%          5.600000
# max         20.200000
# Name: Evaporation, dtype: float64

# %%
df["WindSpeed9am"]=outliers_remove("WindSpeed9am",59.0)

# %%
df["WindSpeed9am"].describe()
# Out:
# count    36261.000000
# mean        14.193265
# std          8.905769
# min          0.000000
# 25%          7.000000
# 50%         13.000000
# 75%         19.000000
# max         59.000000
# Name: WindSpeed9am, dtype: float64

# %%
df["WindSpeed3pm"]=outliers_remove("WindSpeed3pm",57.0)

# %%
df["WindSpeed3pm"].describe()
# Out:
# count    36261.000000
# mean        18.878630
# std          8.714056
# min          0.000000
# 25%         13.000000
# 50%         19.000000
# 75%         24.000000
# max         57.000000
# Name: WindSpeed3pm, dtype: float64

# %%
df.columns
# Out:
# Index(['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
df.head()
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0        Hobart      5.1     14.3       0.0          1.8       8.9
# 1    Launceston      1.1     14.5       0.4          4.6       8.4
# 2   Williamtown     19.7     26.2       0.0          7.2       7.2
# 3  PerthAirport     16.6     28.0       0.0          9.0      11.3
# 4     GoldCoast     14.6     25.3       0.0          4.6       8.4
#
#   WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 0          NW           30.0        WSW        SSE  ...       1022.2
# 1         SSW           50.0          E         SW  ...       1002.4
# 2         SSE           41.0        SSE        SSE  ...       1021.9
# 3          SW           54.0        SSE         SW  ...       1014.9
# 4         NNW           43.0        WNW          N  ...       1015.0
#
#    Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  Month  \
# 0       1.0       1.0      9.1     13.3         No            No  2009      5
# 1       5.0       5.0      1.3     13.7         No            No  2009      7
# 2       6.0       4.0     22.7     24.4         No            No  2010      2
# 3       6.0       1.0     20.0     26.1         No            No  2010      3
# 4       5.0       5.0     22.2     22.6         No            No  2010      9
#
#    Day
# 0   18
# 1    3
# 2   18
# 3    4
# 4    9
#
# [5 rows x 25 columns]

# %%
df[numerical]
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          5.1     14.3       0.0          1.8       8.9           30.0
# 1          1.1     14.5       0.4          4.6       8.4           50.0
# 2         19.7     26.2       0.0          7.2       7.2           41.0
# 3         16.6     28.0       0.0          9.0      11.3           54.0
# 4         14.6     25.3       0.0          4.6       8.4           43.0
# ...        ...      ...       ...          ...       ...            ...
# 36876     10.1     14.2       3.2          3.4       0.0           46.0
# 36877      6.3     26.0       0.0          5.0      10.6           37.0
# 36878     20.5     31.7       0.0          7.0      11.1           37.0
# 36879      6.3     23.3       0.0          5.2      11.6           39.0
# 36880      9.4     26.3       0.0          4.8      12.2           35.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               7.0           6.0         65.0         47.0       1023.1
# 1               7.0          24.0         99.0         46.0       1001.5
# 2              19.0          31.0         48.0         50.0       1020.9
# 3              28.0          33.0         50.0         41.0       1018.3
# 4               6.0          28.0         64.0         67.0       1020.3
# ...             ...           ...          ...          ...          ...
# 36876          19.0          15.0         84.0         81.0       1016.2
# 36877           9.0          26.0         38.0         45.0       1024.2
# 36878          20.0          13.0         54.0         39.0       1012.6
# 36879           9.0          20.0         50.0         41.0       1023.9
# 36880          15.0          20.0         50.0         28.0       1017.5
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  Year  Month  Day
# 0           1022.2       1.0       1.0      9.1     13.3  2009      5   18
# 1           1002.4       5.0       5.0      1.3     13.7  2009      7    3
# 2           1021.9       6.0       4.0     22.7     24.4  2010      2   18
# 3           1014.9       6.0       1.0     20.0     26.1  2010      3    4
# 4           1015.0       5.0       5.0     22.2     22.6  2010      9    9
# ...            ...       ...       ...      ...      ...   ...    ...  ...
# 36876       1014.5       7.0       8.0     10.4     13.9  2011      6   14
# 36877       1021.5       1.0       1.0     18.4     23.5  2010      9   24
# 36878       1009.0       2.0       5.0     25.7     30.5  2011      5    6
# 36879       1019.9       0.0       1.0     16.4     20.9  2010     10   12
# 36880       1014.7       4.0       4.0     16.7     25.3  2010     12   22
#
# [36261 rows x 19 columns]

# %%
df[categorical1]
# Out:
#            Location WindGustDir WindDir9am WindDir3pm RainToday
# 0            Hobart          NW        WSW        SSE        No
# 1        Launceston         SSW          E         SW        No
# 2       Williamtown         SSE        SSE        SSE        No
# 3      PerthAirport          SW        SSE         SW        No
# 4         GoldCoast         NNW        WNW          N        No
# ...             ...         ...        ...        ...       ...
# 36876         Perth         NNE        NNE          N       Yes
# 36877  PerthAirport           W          N        WSW        No
# 36878        Darwin           E          E        ESE        No
# 36879         Perth         SSW          E        SSW        No
# 36880     Nuriootpa          SE        ENE        WSW        No
#
# [36261 rows x 5 columns]

# %%
X=df.drop("RainTomorrow",axis=1)
y=df["RainTomorrow"]

# %%
X
# Out:
#            Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            Hobart      5.1     14.3       0.0          1.8       8.9
# 1        Launceston      1.1     14.5       0.4          4.6       8.4
# 2       Williamtown     19.7     26.2       0.0          7.2       7.2
# 3      PerthAirport     16.6     28.0       0.0          9.0      11.3
# 4         GoldCoast     14.6     25.3       0.0          4.6       8.4
# ...             ...      ...      ...       ...          ...       ...
# 36876         Perth     10.1     14.2       3.2          3.4       0.0
# 36877  PerthAirport      6.3     26.0       0.0          5.0      10.6
# 36878        Darwin     20.5     31.7       0.0          7.0      11.1
# 36879         Perth      6.3     23.3       0.0          5.2      11.6
# 36880     Nuriootpa      9.4     26.3       0.0          4.8      12.2
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure9am  \
# 0              NW           30.0        WSW        SSE  ...       1023.1
# 1             SSW           50.0          E         SW  ...       1001.5
# 2             SSE           41.0        SSE        SSE  ...       1020.9
# 3              SW           54.0        SSE         SW  ...       1018.3
# 4             NNW           43.0        WNW          N  ...       1020.3
# ...           ...            ...        ...        ...  ...          ...
# 36876         NNE           46.0        NNE          N  ...       1016.2
# 36877           W           37.0          N        WSW  ...       1024.2
# 36878           E           37.0          E        ESE  ...       1012.6
# 36879         SSW           39.0          E        SSW  ...       1023.9
# 36880          SE           35.0        ENE        WSW  ...       1017.5
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  Year  \
# 0           1022.2       1.0       1.0      9.1     13.3         No  2009
# 1           1002.4       5.0       5.0      1.3     13.7         No  2009
# 2           1021.9       6.0       4.0     22.7     24.4         No  2010
# 3           1014.9       6.0       1.0     20.0     26.1         No  2010
# 4           1015.0       5.0       5.0     22.2     22.6         No  2010
# ...            ...       ...       ...      ...      ...        ...   ...
# 36876       1014.5       7.0       8.0     10.4     13.9        Yes  2011
# 36877       1021.5       1.0       1.0     18.4     23.5         No  2010
# 36878       1009.0       2.0       5.0     25.7     30.5         No  2011
# 36879       1019.9       0.0       1.0     16.4     20.9         No  2010
# 36880       1014.7       4.0       4.0     16.7     25.3         No  2010
#
#        Month  Day
# 0          5   18
# 1          7    3
# 2          2   18
# 3          3    4
# 4          9    9
# ...      ...  ...
# 36876      6   14
# 36877      9   24
# 36878      5    6
# 36879     10   12
# 36880     12   22
#
# [36261 rows x 24 columns]

# %%
y
# Out:
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 36876    Yes
# 36877     No
# 36878     No
# 36879     No
# 36880     No
# Name: RainTomorrow, Length: 36261, dtype: object

# %%
X_numerical=X.drop(["RainToday","Location","WindGustDir","WindDir9am","WindDir3pm"],axis=1)

# %%
X_numerical.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm', 'Year', 'Month', 'Day'],
#       dtype='object')

# %%
X_numerical
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          5.1     14.3       0.0          1.8       8.9           30.0
# 1          1.1     14.5       0.4          4.6       8.4           50.0
# 2         19.7     26.2       0.0          7.2       7.2           41.0
# 3         16.6     28.0       0.0          9.0      11.3           54.0
# 4         14.6     25.3       0.0          4.6       8.4           43.0
# ...        ...      ...       ...          ...       ...            ...
# 36876     10.1     14.2       3.2          3.4       0.0           46.0
# 36877      6.3     26.0       0.0          5.0      10.6           37.0
# 36878     20.5     31.7       0.0          7.0      11.1           37.0
# 36879      6.3     23.3       0.0          5.2      11.6           39.0
# 36880      9.4     26.3       0.0          4.8      12.2           35.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               7.0           6.0         65.0         47.0       1023.1
# 1               7.0          24.0         99.0         46.0       1001.5
# 2              19.0          31.0         48.0         50.0       1020.9
# 3              28.0          33.0         50.0         41.0       1018.3
# 4               6.0          28.0         64.0         67.0       1020.3
# ...             ...           ...          ...          ...          ...
# 36876          19.0          15.0         84.0         81.0       1016.2
# 36877           9.0          26.0         38.0         45.0       1024.2
# 36878          20.0          13.0         54.0         39.0       1012.6
# 36879           9.0          20.0         50.0         41.0       1023.9
# 36880          15.0          20.0         50.0         28.0       1017.5
#
#        Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  Year  Month  Day
# 0           1022.2       1.0       1.0      9.1     13.3  2009      5   18
# 1           1002.4       5.0       5.0      1.3     13.7  2009      7    3
# 2           1021.9       6.0       4.0     22.7     24.4  2010      2   18
# 3           1014.9       6.0       1.0     20.0     26.1  2010      3    4
# 4           1015.0       5.0       5.0     22.2     22.6  2010      9    9
# ...            ...       ...       ...      ...      ...   ...    ...  ...
# 36876       1014.5       7.0       8.0     10.4     13.9  2011      6   14
# 36877       1021.5       1.0       1.0     18.4     23.5  2010      9   24
# 36878       1009.0       2.0       5.0     25.7     30.5  2011      5    6
# 36879       1019.9       0.0       1.0     16.4     20.9  2010     10   12
# 36880       1014.7       4.0       4.0     16.7     25.3  2010     12   22
#
# [36261 rows x 19 columns]

# %%
X_1 = pd.concat([X_numerical,
                pd.get_dummies(X.RainToday,drop_first=True),
                pd.get_dummies(X.Location,drop_first=True), 
                pd.get_dummies(X.WindGustDir,drop_first=True),
                pd.get_dummies(X.WindDir9am,drop_first=True),
                pd.get_dummies(X.WindDir3pm,drop_first=True)],axis=1)

# %%
X_1.shape
# Out:
# (36261, 110)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_1, y, test_size=0.3,random_state=1)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
abc = AdaBoostClassifier(DecisionTreeClassifier(criterion='gini', max_depth=5,
                                        min_samples_split=2,
                                        max_leaf_nodes=8),
                                         algorithm="SAMME.R",
                                         n_estimators=100,learning_rate=0.2)

# %%
abc.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=5,
#                                                          max_leaf_nodes=8),
#                    learning_rate=0.2, n_estimators=100)

# %%
y_pred=abc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8508134938873059

# %%
from sklearn.model_selection import KFold,cross_val_score,GridSearchCV

# %%
clf_ada = GridSearchCV(abc,{'learning_rate':[0.1,0.2,0.3],'n_estimators':[500,1000,300]})
clf_ada.fit(X_train,y_train)
print(clf_ada.best_score_)
print(clf_ada.best_params_)
# Out:
# 0.8479238094262463
# {'learning_rate': 0.2, 'n_estimators': 100}

# %%
y_pred=clf_ada.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8509054141005608
